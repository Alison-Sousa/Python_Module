# %%
inteiro = int(input (" Escreve um valor inteiro tio..."))
real = float(input (" Escreve um valor inteiro tio..."))
string = input('Campeao em 2012? ')
resultado = inteiro + real
mensagem = string + "..." + str(resultado)
print(inteiro)
print(real)
print(mensagem, " Receita em milhões")
# Out:
#  Escreve um valor inteiro tio...10
#  Escreve um valor inteiro tio...5.6
# Campeao em 2012? Corinthians
# 10
# 5.6
# Corinthians...15.6  Receita em milhões

# %% [markdown]
# **Aula 1 e 2**

# %% [markdown]
# Exemplo numérico

# %%
a = 20
b = 15

resultado = a*b
print("1) O valor da multiplicação, é esse meu caro...", resultado)

resultado = a**b
print("2) O valor da potencia, é esse meu caro...", resultado)

resultado = a/b
print("3) O valor da divisão, é esse meu caro...", resultado)

resultado = a//b
print("4) O valor da divisão por inteiros, é esse meu caro...", resultado)

resultado = a%b
print("5) O valor percentual, é esse meu caro...", resultado)
# Out:
# 1) O valor da multiplicação, é esse meu caro... 300
# 2) O valor da potencia, é esse meu caro... 32768000000000000000
# 3) O valor da divisão, é esse meu caro... 1.3333333333333333
# 4) O valor da divisão por inteiros, é esse meu caro... 1
# 5) O valor percentual, é esse meu caro... 5

# %% [markdown]
# **# Exercicio 1**
#
# Escreva os programas utilizando a linguagem Python para resolver os problemas a seguir:
#
# Ler 4 valores, calcular a média entre eles e apresentar o resultado.

# %%
x1 = 5.4
x2 = 5
x3 = 5
x4 = 10

resultado_media=(x1 + x2+ x3+ x4)/4

print(" A média da resultado é essa meu filho", resultado_media)
# Out:
#  A média da resultado é essa meu filho 6.35

# %% [markdown]
# **# Exercicio 2**
#
# Ler o nome de um produto, o seu valor e a quantidade comprada e apresentar uma mensagem contendo o nome do produto, o seu valor unitário e o valor total da compra.

# %%
produto = "Caneca_Corinthians"
preco = 500.89
quantidade = 10

resultado = float(preco*quantidade)

print("O nome do produto é...", produto)

print("O preço do produto é...", preco)

print("A quantidade do produto é...", quantidade)


print("O valor total da sua compra é...", resultado)
# Out:
# O nome do produto é... Caneca_Corinthians
# O preço do produto é... 500.89
# A quantidade do produto é... 10
# O valor total da sua compra é... 5008.9

# %% [markdown]
# **Aula 3**

# %%
Ler dois valores, calcular a soma deles e verificar se é par ou impar

# %%
x1 = float(input(" Digite qualquer valor para x1  "))
x2 = float(input(" Digite qualquer valor para x2  "))

soma = x1 + x2
 
if (soma%2==0):
  print(' A soma é par')
else: 
  print(' A soma é impar')
# Out:
#  Digite qualquer valor para x1  10.5
#  Digite qualquer valor para x2  11.6893734
#  A soma é impar

# %% [markdown]
# **#Exercicio 3**

# %% [markdown]
# Para ser aprovado em uma disciplina o aluno precisa obter média final maior ou igual a 7,00. Considere que em uma determinada disciplina ele realiza 3 atividades com os seguintes pesos: Prova – peso 45%, Projeto – peso 25%, Atividades – peso 30%. Faça um programa para receber o nome da disciplina, as notas que o aluno obteve em cada atividade, calcule e mostre a média final e o resultado: Aprovado ou Reprovado.

# %%
disciplina = input('Digite o nome de sua disciplina ')
#notas
prova = float(input(" Digite a nota da prova "))
projeto = float(input(" Digite a nota do projeto "))
atividade = float(input(" Digite a nota da atividade "))

peso_1 = prova*0.45
peso_2 = projeto*0.25
peso_3 = atividade*0.30

nota_final= peso_1 + peso_2 + peso_3

if nota_final >= 7.00:
  print('Aluno aprovado')
else:
  print('Aluno reprovado')
# Out:
# Digite o nome de sua disciplina Calculo
#  Digite a nota da prova 7.5
#  Digite a nota do projeto 6
#  Digite a nota da atividade 8.5
# Aluno aprovado

# %% [markdown]
# **#Exercicio 4**

# %% [markdown]
# Considere a situação em que um sistema que controla a temperatura ambiente de uma determinada sala precisa receber a temperatura e, caso acima de 28 graus, precisa mostrar uma mensagem indicando que é necessário acionar o ar condicionado. Escreva um programa que receba a temperatura e verifique isso.

# %%
temperatura = float (input(" Digite a temperatura do ambiente no momento "))
if temperatura >28:
  print(' Urgente é fogo, ligue o ar condicionado')
else:
  print(' Ambiente está razoavel')
# Out:
#  Digite a temperatura do ambiente no momento 29
#  Urgente é fogo, ligue o ar condicionado

# %% [markdown]
# **Aula 4**
